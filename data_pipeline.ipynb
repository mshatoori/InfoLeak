# %%
import logging
import sys
from collections import defaultdict

from scapy.all import sniff
from scapy.layers.inet import ICMP
from scapy.layers.tls.record import TLS, TLSApplicationData

sys.path.insert(0, "/home/Mohammad/Workspace/InfoLeak/DoHlyzer")

from meter.flow import Flow
from meter.features.context.packet_direction import PacketDirection 

from meter.time_series.processor import Processor

# %%
def process_pcap(path, outdir):
    packets = sniff(offline=path, filter='icmp or port 443')

    doh_traffic = defaultdict(list)
    
    host_name = None
    for p in packets:
        if ICMP in p and p[ICMP].type == 0:  # Echo response
            host_name = p[ICMP].payload.load.decode()
            if host_name == 'DONE':
                logging.info('Yay!')
                break
            logging.info('Analyzing %s', host_name)
    
        if host_name is not None:
            if TLS in p and TLSApplicationData in p and len(p[TLSApplicationData]) >= 40:
                doh_traffic[host_name].append(p)

    for idx, domain in enumerate(doh_traffic):
        domain_packets = doh_traffic[domain]
        
        p = domain_packets[0]
        logging.warning('#%d domain=%s', idx, domain)
        direction = PacketDirection.FORWARD if p.pkttype == 4 else PacketDirection.REVERSE 
        f = Flow(p, direction)
    
        for p in domain_packets:
            direction = PacketDirection.FORWARD if p.pkttype == 4 else PacketDirection.REVERSE
            f.add_packet(p, direction)
    
        proc = Processor(f)
        flow_clumps = proc.create_flow_clumps_container()
        flow_clumps.to_json_single(f'{outdir}/{domain}.json')

# %%
import os

def run(i):
    path = f'./dataset-top1000-padded/{i}/doh.pcap'
    outdir = f'./results/padded/{i}'

    logging.warning(f'Processing {path}')
    os.makedirs(outdir, exist_ok=True)
    process_pcap(path, outdir)

# %%
import gc

for i in range(1, 4):
    gc.collect()
    run(i)
# Out:
# WARNING:root:Processing ./dataset-top1000-padded/1/doh.pcap
# WARNING:scapy.runtime:Unknown cipher suite 11659155 from ClientMasterKey
# WARNING:scapy.runtime:Unknown cipher suite 3407180 from ClientMasterKey
# WARNING:scapy.runtime:Unknown cipher suite 3407180 from ClientMasterKey
# WARNING:root:#0 domain=google.com
# WARNING:root:#1 domain=youtube.com
# WARNING:root:#2 domain=facebook.com
# WARNING:root:#3 domain=tmall.com
# WARNING:root:#4 domain=baidu.com
# WARNING:root:#5 domain=qq.com
# WARNING:root:#6 domain=sohu.com
# WARNING:root:#7 domain=taobao.com
# WARNING:root:#8 domain=login.tmall.com
# WARNING:root:#9 domain=wikipedia.org
# WARNING:root:#10 domain=yahoo.com
# WARNING:root:#11 domain=amazon.com
# WARNING:root:#12 domain=360.cn
# WARNING:root:#13 domain=jd.com
# WARNING:root:#14 domain=weibo.com
# WARNING:root:#15 domain=sina.com.cn
# WARNING:root:#16 domain=pages.tmall.com
# WARNING:root:#17 domain=live.com
# WARNING:root:#18 domain=reddit.com
# WARNING:root:#19 domain=vk.com
# WARNING:root:#20 domain=okezone.com
# WARNING:root:#21 domain=netflix.com
# WARNING:root:#22 domain=blogspot.com
# WARNING:root:#23 domain=office.com
# WARNING:root:#24 domain=alipay.com
# WARNING:root:#25 domain=xinhuanet.com
# WARNING:root:#26 domain=csdn.net
# WARNING:root:#27 domain=instagram.com
# WARNING:root:#28 domain=yahoo.co.jp
# WARNING:root:#29 domain=aliexpress.com
# WARNING:root:#30 domain=microsoft.com
# WARNING:root:#31 domain=bing.com
# WARNING:root:#32 domain=google.com.hk
# WARNING:root:#33 domain=stackoverflow.com
# WARNING:root:#34 domain=spotify.com
# WARNING:root:#35 domain=naver.com
# WARNING:root:#36 domain=twitter.com
# WARNING:root:#37 domain=tribunnews.com
# WARNING:root:#38 domain=livejasmin.com
# WARNING:root:#39 domain=ebay.com
# WARNING:root:#40 domain=twitch.tv
# WARNING:root:#41 domain=amazon.co.jp
# WARNING:root:#42 domain=force.com
# WARNING:root:#43 domain=google.co.in
# WARNING:root:#44 domain=microsoftonline.com
# WARNING:root:#45 domain=tianya.cn
# WARNING:root:#46 domain=apple.com
# WARNING:root:#47 domain=myshopify.com
# WARNING:root:#48 domain=pornhub.com
# WARNING:root:#49 domain=yandex.ru
# WARNING:root:#50 domain=msn.com
# WARNING:root:#51 domain=adobe.com
# WARNING:root:#52 domain=panda.tv
# WARNING:root:#53 domain=linkedin.com
# WARNING:root:#54 domain=zhanqi.tv
# WARNING:root:#55 domain=dropbox.com
# WARNING:root:#56 domain=wordpress.com
# WARNING:root:#57 domain=amazon.in
# WARNING:root:#58 domain=caijing.com.cn
# WARNING:root:#59 domain=mail.ru
# WARNING:root:#60 domain=imdb.com
# WARNING:root:#61 domain=china.com.cn
# WARNING:root:#62 domain=mama.cn
# WARNING:root:#63 domain=medium.com
# WARNING:root:#64 domain=google.com.br
# WARNING:root:#65 domain=bongacams.com
# WARNING:root:#66 domain=google.co.jp
# WARNING:root:#67 domain=hao123.com
# WARNING:root:#68 domain=amazon.co.uk
# WARNING:root:#69 domain=amazonaws.com
# WARNING:root:#70 domain=detik.com
# WARNING:root:#71 domain=rednet.cn
# WARNING:root:#72 domain=google.de
# WARNING:root:#73 domain=whatsapp.com
# WARNING:root:#74 domain=booking.com
# WARNING:root:#75 domain=xvideos.com
# WARNING:root:#76 domain=detail.tmall.com
# WARNING:root:#77 domain=amazon.de
# WARNING:root:#78 domain=ok.ru
# WARNING:root:#79 domain=instructure.com
# WARNING:root:#80 domain=tumblr.com
# WARNING:root:#81 domain=soso.com
# WARNING:root:#82 domain=bbc.com
# WARNING:root:#83 domain=sogou.com
# WARNING:root:#84 domain=google.cn
# WARNING:root:#85 domain=github.com
# WARNING:root:#86 domain=chase.com
# WARNING:root:#87 domain=paypal.com
# WARNING:root:#88 domain=espn.com
# WARNING:root:#89 domain=indeed.com
# WARNING:root:#90 domain=huanqiu.com
# WARNING:root:#91 domain=xhamster.com
# WARNING:root:#92 domain=google.ru
# WARNING:root:#93 domain=yy.com
# WARNING:root:#94 domain=nytimes.com
# WARNING:root:#95 domain=cnn.com
# WARNING:root:#96 domain=imgur.com
# WARNING:root:#97 domain=soundcloud.com
# WARNING:root:#98 domain=babytree.com
# WARNING:root:#99 domain=onlinesbi.com
# WARNING:root:#100 domain=17ok.com
# WARNING:root:#101 domain=stackexchange.com
# WARNING:root:#102 domain=walmart.com
# WARNING:root:#103 domain=aparat.com
# WARNING:root:#104 domain=bbc.co.uk
# WARNING:root:#105 domain=fandom.com
# WARNING:root:#106 domain=1688.com
# WARNING:root:#107 domain=ettoday.net
# WARNING:root:#108 domain=udemy.com
# WARNING:root:#109 domain=google.fr
# WARNING:root:#110 domain=google.it
# WARNING:root:#111 domain=freepik.com
# WARNING:root:#112 domain=so.com
# WARNING:root:#113 domain=shutterstock.com
# WARNING:root:#114 domain=pixnet.net
# WARNING:root:#115 domain=google.es
# WARNING:root:#116 domain=flipkart.com
# WARNING:root:#117 domain=kompas.com
# WARNING:root:#118 domain=etsy.com
# WARNING:root:#119 domain=nih.gov
# WARNING:root:#120 domain=roblox.com
# WARNING:root:#121 domain=mailchimp.com
# WARNING:root:#122 domain=sindonews.com
# WARNING:root:#123 domain=alibaba.com
# WARNING:root:#124 domain=google.com.tw
# WARNING:root:#125 domain=wetransfer.com
# WARNING:root:#126 domain=thestartmagazine.com
# WARNING:root:#127 domain=theguardian.com
# WARNING:root:#128 domain=jrj.com.cn
# WARNING:root:#129 domain=liputan6.com
# WARNING:root:#130 domain=salesforce.com
# WARNING:root:#131 domain=uol.com.br
# WARNING:root:#132 domain=google.co.uk
# WARNING:root:#133 domain=zendesk.com
# WARNING:root:#134 domain=indiatimes.com
# WARNING:root:#135 domain=canva.com
# WARNING:root:#136 domain=daum.net
# WARNING:root:#137 domain=office365.com
# WARNING:root:#138 domain=tokopedia.com
# WARNING:root:#139 domain=google.com.mx
# WARNING:root:#140 domain=google.com.sg
# WARNING:root:#141 domain=cnet.com
# WARNING:root:#142 domain=mercadolivre.com.br
# WARNING:root:#143 domain=wikihow.com
# WARNING:root:#144 domain=cnblogs.com
# WARNING:root:#145 domain=bilibili.com
# WARNING:root:#146 domain=digikala.com
# WARNING:root:#147 domain=bestbuy.com
# WARNING:root:#148 domain=slideshare.net
# WARNING:root:#149 domain=grid.id
# WARNING:root:#150 domain=okta.com
# WARNING:root:#151 domain=washingtonpost.com
# WARNING:root:#152 domain=t.co
# WARNING:root:#153 domain=google.com.tr
# WARNING:root:#154 domain=pinterest.com
# WARNING:root:#155 domain=yao.tmall.com
# WARNING:root:#156 domain=vice.com
# WARNING:root:#157 domain=savefrom.net
# WARNING:root:#158 domain=ebay.de
# WARNING:root:#159 domain=rakuten.co.jp
# WARNING:root:#160 domain=zhihu.com
# WARNING:root:#161 domain=discordapp.com
# WARNING:root:#162 domain=grammarly.com
# WARNING:root:#163 domain=globo.com
# WARNING:root:#164 domain=researchgate.net
# WARNING:root:#165 domain=w3schools.com
# WARNING:root:#166 domain=vimeo.com
# WARNING:root:#167 domain=ups.com
# WARNING:root:#168 domain=avito.ru
# WARNING:root:#169 domain=craigslist.org
# WARNING:root:#170 domain=archive.org
# WARNING:root:#171 domain=xnxx.com
# WARNING:root:#172 domain=line.me
# WARNING:root:#173 domain=telegram.org
# WARNING:root:#174 domain=godaddy.com
# WARNING:root:#175 domain=metropoles.com
# WARNING:root:#176 domain=hdfcbank.com
# WARNING:root:#177 domain=forbes.com
# WARNING:root:#178 domain=chaturbate.com
# WARNING:root:#179 domain=speedtest.net
# WARNING:root:#180 domain=6.cn
# WARNING:root:#181 domain=amazon.ca
# WARNING:root:#182 domain=duckduckgo.com
# WARNING:root:#183 domain=aliyun.com
# WARNING:root:#184 domain=wellsfargo.com
# WARNING:root:#185 domain=ask.com
# WARNING:root:#186 domain=mediafire.com
# WARNING:root:#187 domain=abs-cbn.com
# WARNING:root:#188 domain=amazon.it
# WARNING:root:#189 domain=3c.tmall.com
# WARNING:root:#190 domain=amazon.fr
# WARNING:root:#191 domain=ltn.com.tw
# WARNING:root:#192 domain=jiameng.com
# WARNING:root:#193 domain=mozilla.org
# WARNING:root:#194 domain=scribd.com
# WARNING:root:#195 domain=academia.edu
# WARNING:root:#196 domain=varzesh3.com
# WARNING:root:#197 domain=telewebion.com
# WARNING:root:#198 domain=google.com.sa
# WARNING:root:#199 domain=gmw.cn
# WARNING:root:#200 domain=163.com
# WARNING:root:#201 domain=fedex.com
# WARNING:root:#202 domain=google.com.eg
# WARNING:root:#203 domain=thepiratebay.org
# WARNING:root:#204 domain=manoramaonline.com
# WARNING:root:#205 domain=jianshu.com
# WARNING:root:#206 domain=bet365.com
# WARNING:root:#207 domain=google.ca
# WARNING:root:#208 domain=dailymotion.com
# WARNING:root:#209 domain=ilovepdf.com
# WARNING:root:#210 domain=zillow.com
# WARNING:root:#211 domain=gohoi.com
# WARNING:root:#212 domain=quora.com
# WARNING:root:#213 domain=unsplash.com
# WARNING:root:#214 domain=thesaurus.com
# WARNING:root:#215 domain=businessinsider.com
# WARNING:root:#216 domain=y2mate.com
# WARNING:root:#217 domain=primevideo.com
# WARNING:root:#218 domain=gome.com.cn
# WARNING:root:#219 domain=trello.com
# WARNING:root:#220 domain=wix.com
# WARNING:root:#221 domain=tistory.com
# WARNING:root:#222 domain=usps.com
# WARNING:root:#223 domain=setn.com
# WARNING:root:#224 domain=taboola.com
# WARNING:root:#225 domain=chouftv.ma
# WARNING:root:#226 domain=mega.nz
# WARNING:root:#227 domain=amazon.es
# WARNING:root:#228 domain=iqiyi.com
# WARNING:root:#229 domain=icicibank.com
# WARNING:root:#230 domain=google.co.id
# WARNING:root:#231 domain=capitalone.com
# WARNING:root:#232 domain=momoshop.com.tw
# WARNING:root:#233 domain=ladbible.com
# WARNING:root:#234 domain=evernote.com
# WARNING:root:#235 domain=sciencedirect.com
# WARNING:root:#236 domain=thethao247.vn
# WARNING:root:#237 domain=ebay.co.uk
# WARNING:root:#238 domain=messenger.com
# WARNING:root:#239 domain=hulu.com
# WARNING:root:#240 domain=healthline.com
# WARNING:root:#241 domain=google.com.ar
# WARNING:root:#242 domain=sigonews.com
# WARNING:root:#243 domain=nicovideo.jp
# WARNING:root:#244 domain=google.co.th
# WARNING:root:#245 domain=otvfoco.com.br
# WARNING:root:#246 domain=nvzhuang.tmall.com
# WARNING:root:#247 domain=suara.com
# WARNING:root:#248 domain=gfycat.com
# WARNING:root:#249 domain=youm7.com
# WARNING:root:#250 domain=skype.com
# WARNING:root:#251 domain=idntimes.com
# WARNING:root:#252 domain=sportbible.com
# WARNING:root:#253 domain=foxnews.com
# WARNING:root:#254 domain=weebly.com
# WARNING:root:#255 domain=reverso.net
# WARNING:root:#256 domain=uniqlo.tmall.com
# WARNING:root:#257 domain=scol.com.cn
# WARNING:root:#258 domain=target.com
# WARNING:root:#259 domain=itfactly.com
# WARNING:root:#260 domain=yts.lt
# WARNING:root:#261 domain=food.tmall.com
# WARNING:root:#262 domain=quizlet.com
# WARNING:root:#263 domain=youporn.com
# WARNING:root:#264 domain=geeksforgeeks.org
# WARNING:root:#265 domain=breitbart.com
# WARNING:root:#266 domain=box.com
# WARNING:root:#267 domain=techofires.com
# WARNING:root:#268 domain=dailymail.co.uk
# WARNING:root:#269 domain=asos.com
# WARNING:root:#270 domain=youth.cn
# WARNING:root:#271 domain=blogger.com
# WARNING:root:#272 domain=zoom.us
# WARNING:root:#273 domain=subject.tmall.com
# WARNING:root:#274 domain=namnak.com
# WARNING:root:#275 domain=ameblo.jp
# WARNING:root:#276 domain=tripadvisor.com
# WARNING:root:#277 domain=nianhuo.tmall.com
# WARNING:root:#278 domain=google.pl
# WARNING:root:#279 domain=allegro.pl
# WARNING:root:#280 domain=ideapuls.com
# WARNING:root:#281 domain=softonic.com
# WARNING:root:#282 domain=smallpdf.com
# WARNING:root:#283 domain=pexels.com
# WARNING:root:#284 domain=kumparan.com
# WARNING:root:#285 domain=bolasport.com
# WARNING:root:#286 domain=patria.org.ve
# WARNING:root:#287 domain=sberbank.ru
# WARNING:root:#288 domain=goodreads.com
# WARNING:root:#289 domain=gosuslugi.ru
# WARNING:root:#290 domain=eastday.com
# WARNING:root:#291 domain=googlevideo.com
# WARNING:root:#292 domain=google.co.kr
# WARNING:root:#293 domain=ndtv.com
# WARNING:root:#294 domain=merdeka.com
# WARNING:root:#295 domain=gstatic.com
# WARNING:root:#296 domain=cambridge.org
# WARNING:root:#297 domain=giphy.com
# WARNING:root:#298 domain=pinimg.com
# WARNING:root:#299 domain=ebay-kleinanzeigen.de
# WARNING:root:#300 domain=steampowered.com
# WARNING:root:#301 domain=ikea.com
# WARNING:root:#302 domain=twimg.com
# WARNING:root:#303 domain=weather.com
# WARNING:root:#304 domain=behance.net
# WARNING:root:#305 domain=wikimedia.org
# WARNING:root:#306 domain=postlnk.com
# WARNING:root:#307 domain=samsung.com
# WARNING:root:#308 domain=cnnindonesia.com
# WARNING:root:#309 domain=fc2.com
# WARNING:root:#310 domain=list.tmall.com
# WARNING:root:#311 domain=steamcommunity.com
# WARNING:root:#312 domain=rakuten.com
# WARNING:root:#313 domain=tradingview.com
# WARNING:root:#314 domain=airbnb.com
# WARNING:root:#315 domain=sahibinden.com
# WARNING:root:#316 domain=cnbc.com
# WARNING:root:#317 domain=namasha.com
# WARNING:root:#318 domain=google.com.au
# WARNING:root:#319 domain=investing.com
# WARNING:root:#320 domain=doubleclick.net
# WARNING:root:#321 domain=aimer.tmall.com
# WARNING:root:#322 domain=glassdoor.com
# WARNING:root:#323 domain=ebc.net.tw
# WARNING:root:#324 domain=cloudfront.net
# WARNING:root:#325 domain=buzzfeed.com
# WARNING:root:#326 domain=kompasiana.com
# WARNING:root:#327 domain=9gag.com
# WARNING:root:#328 domain=brilio.net
# WARNING:root:#329 domain=spankbang.com
# WARNING:root:#330 domain=rt.com
# WARNING:root:#331 domain=kakao.com
# WARNING:root:#332 domain=lazada.sg
# WARNING:root:#333 domain=redd.it
# WARNING:root:#334 domain=hp.com
# WARNING:root:#335 domain=cowner.net
# WARNING:root:#336 domain=patch.com
# WARNING:root:#337 domain=neiyi.tmall.com
# WARNING:root:#338 domain=hotstar.com
# WARNING:root:#339 domain=sex.com
# WARNING:root:#340 domain=banvenez.com
# WARNING:root:#341 domain=51.la
# WARNING:root:#342 domain=gmx.net
# WARNING:root:#343 domain=rambler.ru
# WARNING:root:#344 domain=macys.com
# WARNING:root:#345 domain=iqoption.com
# WARNING:root:#346 domain=myhome.tmall.com
# WARNING:root:#347 domain=surveymonkey.com
# WARNING:root:#348 domain=dostor.org
# WARNING:root:#349 domain=deviantart.com
# WARNING:root:#350 domain=eventbrite.com
# WARNING:root:#351 domain=naukri.com
# WARNING:root:#352 domain=shaparak.ir
# WARNING:root:#353 domain=homedepot.com
# WARNING:root:#354 domain=mercadolibre.com.mx
# WARNING:root:#355 domain=livejournal.com
# WARNING:root:#356 domain=onlinevideoconverter.com
# WARNING:root:#357 domain=wordreference.com
# WARNING:root:#358 domain=mgid.com
# WARNING:root:#359 domain=mercadolibre.com.ar
# WARNING:root:#360 domain=hootsuite.com
# WARNING:root:#361 domain=51sole.com
# WARNING:root:#362 domain=alwafd.news
# WARNING:root:#363 domain=dell.com
# WARNING:root:#364 domain=douban.com
# WARNING:root:#365 domain=bp.blogspot.com
# WARNING:root:#366 domain=pulzo.com
# WARNING:root:#367 domain=miao.tmall.com
# WARNING:root:#368 domain=n11.com
# WARNING:root:#369 domain=coinmarketcap.com
# WARNING:root:#370 domain=err.tmall.com
# WARNING:root:#371 domain=htopensationclie.info
# WARNING:root:#372 domain=ensonhaber.com
# WARNING:root:#373 domain=aol.com
# WARNING:root:#374 domain=blackboard.com
# WARNING:root:#375 domain=adp.com
# WARNING:root:#376 domain=outbrain.com
# WARNING:root:#377 domain=disneyplus.com
# WARNING:root:#378 domain=bloomberg.com
# WARNING:root:#379 domain=elbalad.news
# WARNING:root:#380 domain=zoho.com
# WARNING:root:#381 domain=slickdeals.net
# WARNING:root:#382 domain=kinopoisk.ru
# WARNING:root:#383 domain=1337x.to
# WARNING:root:#384 domain=wixsite.com
# WARNING:root:#385 domain=popads.net
# WARNING:root:#386 domain=trustpilot.com
# WARNING:root:#387 domain=sourceforge.net
# WARNING:root:#388 domain=genius.com
# WARNING:root:#389 domain=google.gr
# WARNING:root:#390 domain=indiamart.com
# WARNING:root:#391 domain=slack.com
# WARNING:root:#392 domain=serconmp.com
# WARNING:root:#393 domain=google.com.vn
# WARNING:root:#394 domain=wish.com
# WARNING:root:#395 domain=americanas.com.br
# WARNING:root:#396 domain=biobiochile.cl
# WARNING:root:#397 domain=amazon.cn
# WARNING:root:#398 domain=divar.ir
# WARNING:root:#399 domain=irctc.co.in
# WARNING:root:#400 domain=google.com.ua
# WARNING:root:#401 domain=uselnk.com
# WARNING:root:#402 domain=souq.com
# WARNING:root:#403 domain=justdial.com
# WARNING:root:#404 domain=namu.wiki
# WARNING:root:#405 domain=files.wordpress.com
# WARNING:root:#406 domain=issuu.com
# WARNING:root:#407 domain=xfinity.com
# WARNING:root:#408 domain=oracle.com
# WARNING:root:#409 domain=citi.com
# WARNING:root:#410 domain=mit.edu
# WARNING:root:#411 domain=ninisite.com
# WARNING:root:#412 domain=web.de
# WARNING:root:#413 domain=webmd.com
# WARNING:root:#414 domain=rutracker.org
# WARNING:root:#415 domain=huaban.com
# WARNING:root:#416 domain=kakaku.com
# WARNING:root:#417 domain=heavy.com
# WARNING:root:#418 domain=dailyfeed.co.uk
# WARNING:root:#419 domain=payoneer.com
# WARNING:root:#420 domain=squarespace.com
# WARNING:root:#421 domain=alodokter.com
# WARNING:root:#422 domain=lee.tmall.com
# WARNING:root:#423 domain=amazon.com.mx
# WARNING:root:#424 domain=gap.tmall.com
# WARNING:root:#425 domain=ecosia.org
# WARNING:root:#426 domain=vtv.vn
# WARNING:root:#427 domain=vnexpress.net
# WARNING:root:#428 domain=mathrubhumi.com
# WARNING:root:#429 domain=nike.com
# WARNING:root:#430 domain=crabsecret.tmall.com
# WARNING:root:#431 domain=pixabay.com
# WARNING:root:#432 domain=hurriyet.com.tr
# WARNING:root:#433 domain=hm.com
# WARNING:root:#434 domain=wildberries.ru
# WARNING:root:#435 domain=gismeteo.ru
# WARNING:root:#436 domain=wsj.com
# WARNING:root:#437 domain=ouedkniss.com
# WARNING:root:#438 domain=rediff.com
# WARNING:root:#439 domain=bancodevenezuela.com
# WARNING:root:#440 domain=intuit.com
# WARNING:root:#441 domain=tutorialspoint.com
# WARNING:root:#442 domain=udn.com
# WARNING:root:#443 domain=youdao.com
# WARNING:root:#444 domain=yandex.com
# WARNING:root:#445 domain=trendyol.com
# WARNING:root:#446 domain=patreon.com
# WARNING:root:#447 domain=weblio.jp
# WARNING:root:#448 domain=ebay.com.au
# WARNING:root:#449 domain=crptgate.com
# WARNING:root:#450 domain=elwatannews.com
# WARNING:root:#451 domain=theverge.com
# WARNING:root:#452 domain=europa.eu
# WARNING:root:#453 domain=brobible.com
# WARNING:root:#454 domain=dmm.co.jp
# WARNING:root:#455 domain=t.me
# WARNING:root:#456 domain=istockphoto.com
# WARNING:root:#457 domain=moneycontrol.com
# WARNING:root:#458 domain=gamepedia.com
# WARNING:root:#459 domain=fiverr.com
# WARNING:root:#460 domain=inquirer.net
# WARNING:root:#461 domain=qoo10.sg
# WARNING:root:#462 domain=usatoday.com
# WARNING:root:#463 domain=td.com
# WARNING:root:#464 domain=investopedia.com
# WARNING:root:#465 domain=banggood.com
# WARNING:root:#466 domain=spao.tmall.com
# WARNING:root:#467 domain=zapier.com
# WARNING:root:#468 domain=olx.ua
# WARNING:root:#469 domain=elsevier.com
# WARNING:root:#470 domain=dbs.com.sg
# WARNING:root:#471 domain=caixa.gov.br
# WARNING:root:#472 domain=kapanlagi.com
# WARNING:root:#473 domain=chinaz.com
# WARNING:root:#474 domain=wayfair.com
# WARNING:root:#475 domain=beytoote.com
# WARNING:root:#476 domain=filimo.com
# WARNING:root:#477 domain=free.fr
# WARNING:root:#478 domain=cdstm.cn
# WARNING:root:#479 domain=norton.com
# WARNING:root:#480 domain=pandora.com
# WARNING:root:#481 domain=tempo.co
# WARNING:root:#482 domain=google.com.pk
# WARNING:root:#483 domain=prothomalo.com
# WARNING:root:#484 domain=zerodha.com
# WARNING:root:#485 domain=in.gr
# WARNING:root:#486 domain=reuters.com
# WARNING:root:#487 domain=chess.com
# WARNING:root:#488 domain=britannica.com
# WARNING:root:#489 domain=jiwu.com
# WARNING:root:#490 domain=ign.com
# WARNING:root:#491 domain=pixiv.net
# WARNING:root:#492 domain=stremanp.com
# WARNING:root:#493 domain=albawabhnews.com
# WARNING:root:#494 domain=google.ro
# WARNING:root:#495 domain=gmanetwork.com
# WARNING:root:#496 domain=springer.com
# WARNING:root:#497 domain=zippyshare.com
# WARNING:root:#498 domain=gearbest.com
# WARNING:root:#499 domain=livedoor.jp
# WARNING:root:#500 domain=theepochtimes.com
# WARNING:root:#501 domain=ca.gov
# WARNING:root:#502 domain=merriam-webster.com
# WARNING:root:#503 domain=redtube.com
# WARNING:root:#504 domain=libero.it
# WARNING:root:#505 domain=kohls.com
# WARNING:root:#506 domain=kickstarter.com
# WARNING:root:#507 domain=playstation.com
# WARNING:root:#508 domain=wp.pl
# WARNING:root:#509 domain=agoda.com
# WARNING:root:#510 domain=nypost.com
# WARNING:root:#511 domain=depositphotos.com
# WARNING:root:#512 domain=kaskus.co.id
# WARNING:root:#513 domain=eksisozluk.com
# WARNING:root:#514 domain=rarbg.to
# WARNING:root:#515 domain=taleo.net
# WARNING:root:#516 domain=104.com.tw
# WARNING:root:#517 domain=google.co.ve
# WARNING:root:#518 domain=wattpad.com
# WARNING:root:#519 domain=gsmarena.com
# WARNING:root:#520 domain=emol.com
# WARNING:root:#521 domain=khanacademy.org
# WARNING:root:#522 domain=tandfonline.com
# WARNING:root:#523 domain=lifo.gr
# WARNING:root:#524 domain=elpais.com
# WARNING:root:#525 domain=coursera.org
# WARNING:root:#526 domain=costco.com
# WARNING:root:#527 domain=marca.com
# WARNING:root:#528 domain=google.be
# WARNING:root:#529 domain=mileroticos.com
# WARNING:root:#530 domain=realtor.com
# WARNING:root:#531 domain=coursehero.com
# WARNING:root:#532 domain=cdninstagram.com
# WARNING:root:#533 domain=newegg.com
# WARNING:root:#534 domain=memurlar.net
# WARNING:root:#535 domain=impress.co.jp
# WARNING:root:#536 domain=google.dz
# WARNING:root:#537 domain=tiktok.com
# WARNING:root:#538 domain=jw.org
# WARNING:root:#539 domain=bhphotovideo.com
# WARNING:root:#540 domain=dkn.tv
# WARNING:root:#541 domain=spanishdict.com
# WARNING:root:#542 domain=nba.com
# WARNING:root:#543 domain=yelp.com
# WARNING:root:#544 domain=internetdownloadmanager.com
# WARNING:root:#545 domain=infobae.com
# WARNING:root:#546 domain=google.com.pe
# WARNING:root:#547 domain=xero.com
# WARNING:root:#548 domain=kuronekoyamato.co.jp
# WARNING:root:#549 domain=basichouse.tmall.com
# WARNING:root:#550 domain=atlassian.net
# WARNING:root:#551 domain=vidio.com
# WARNING:root:#552 domain=marketwatch.com
# WARNING:root:#553 domain=fast.com
# WARNING:root:#554 domain=shopify.com
# WARNING:root:#555 domain=chegg.com
# WARNING:root:#556 domain=t-online.de
# WARNING:root:#557 domain=timeanddate.com
# WARNING:root:#558 domain=jamnews.com
# WARNING:root:#559 domain=banesconline.com
# WARNING:root:#560 domain=atlassian.com
# WARNING:root:#561 domain=accuweather.com
# WARNING:root:#562 domain=study.com
# WARNING:root:#563 domain=news18.com
# WARNING:root:#564 domain=axisbank.co.in
# WARNING:root:#565 domain=bankofamerica.com
# WARNING:root:#566 domain=i5iog3mlrw.com
# WARNING:root:#567 domain=lun.com
# WARNING:root:#568 domain=pchome.com.tw
# WARNING:root:#569 domain=onet.pl
# WARNING:root:#570 domain=klix.ba
# WARNING:root:#571 domain=tencent.com
# WARNING:root:#572 domain=medicalnewstoday.com
# WARNING:root:#573 domain=marriott.com
# WARNING:root:#574 domain=wiktionary.org
# WARNING:root:#575 domain=myworkday.com
# WARNING:root:#576 domain=prezi.com
# WARNING:root:#577 domain=expedia.com
# WARNING:root:#578 domain=oschina.net
# WARNING:root:#579 domain=o3sndvzo25.com
# WARNING:root:#580 domain=indiatoday.in
# WARNING:root:#581 domain=google.co.za
# WARNING:root:#582 domain=narvar.com
# WARNING:root:#583 domain=go.com
# WARNING:root:#584 domain=motor1.com
# WARNING:root:#585 domain=dcard.tw
# WARNING:root:#586 domain=trendingnow.video
# WARNING:root:#587 domain=dhl.de
# WARNING:root:#588 domain=sabq.org
# WARNING:root:#589 domain=makemytrip.com
# WARNING:root:#590 domain=rezka.ag
# WARNING:root:#591 domain=pmlw0efk4x.com
# WARNING:root:#592 domain=nike.tmall.com
# WARNING:root:#593 domain=pngtree.com
# WARNING:root:#594 domain=buffer.com
# WARNING:root:#595 domain=chinadaily.com.cn
# WARNING:root:#596 domain=duolingo.com
# WARNING:root:#597 domain=google.az
# WARNING:root:#598 domain=crunchyroll.com
# WARNING:root:#599 domain=gyazo.com
# WARNING:root:#600 domain=wiley.com
# WARNING:root:#601 domain=ria.ru
# WARNING:root:#602 domain=gmarket.co.kr
# WARNING:root:#603 domain=ogrfi3uyt7.com
# WARNING:root:#604 domain=groupon.com
# WARNING:root:#605 domain=typeform.com
# WARNING:root:#606 domain=qpps.xyz
# WARNING:root:#607 domain=npr.org
# WARNING:root:#608 domain=verizonwireless.com
# WARNING:root:#609 domain=rbc.ru
# WARNING:root:#610 domain=herokuapp.com
# WARNING:root:#611 domain=huffpost.com
# WARNING:root:#612 domain=4exlkjnngs.com
# WARNING:root:#613 domain=teamviewer.com
# WARNING:root:#614 domain=att.com
# WARNING:root:#615 domain=nbcnews.com
# WARNING:root:#616 domain=dictionary.com
# WARNING:root:#617 domain=tabelog.com
# WARNING:root:#618 domain=creditchina.gov.cn
# WARNING:root:#619 domain=cbssports.com
# WARNING:root:#620 domain=qualtrics.com
# WARNING:root:#621 domain=deepl.com
# WARNING:root:#622 domain=animeflv.net
# WARNING:root:#623 domain=umeng.com
# WARNING:root:#624 domain=olx.pl
# WARNING:root:#625 domain=flickr.com
# WARNING:root:#626 domain=php.net
# WARNING:root:#627 domain=creditonebank.com
# WARNING:root:#628 domain=chron.com
# WARNING:root:#629 domain=narcity.com
# WARNING:root:#630 domain=ibm.com
# WARNING:root:#631 domain=premierleague.com
# WARNING:root:#632 domain=zara.com
# WARNING:root:#633 domain=ivi.ru
# WARNING:root:#634 domain=seznam.cz
# WARNING:root:#635 domain=myway.com
# WARNING:root:#636 domain=blog.me
# WARNING:root:#637 domain=studfile.net
# WARNING:root:#638 domain=exoclick.com
# WARNING:root:#639 domain=farsnews.com
# WARNING:root:#640 domain=livescore.com
# WARNING:root:#641 domain=dalfak.com
# WARNING:root:#642 domain=ticketmaster.com
# WARNING:root:#643 domain=gainreel.tmall.com
# WARNING:root:#644 domain=hotels.com
# WARNING:root:#645 domain=rokna.net
# WARNING:root:#646 domain=elmundo.es
# WARNING:root:#647 domain=shutterfly.com
# WARNING:root:#648 domain=hatenablog.com
# WARNING:root:#649 domain=xianjichina.com
# WARNING:root:#650 domain=techradar.com
# WARNING:root:#651 domain=xpx7heciz9.com
# WARNING:root:#652 domain=ozon.ru
# WARNING:root:#653 domain=biblegateway.com
# WARNING:root:#654 domain=360doc.com
# WARNING:root:#655 domain=ultimate-guitar.com
# WARNING:root:#656 domain=americanexpress.com
# WARNING:root:#657 domain=uioxj.xyz
# WARNING:root:#658 domain=anta.tmall.com
# WARNING:root:#659 domain=royalbank.com
# WARNING:root:#660 domain=sarkariresult.com
# WARNING:root:#661 domain=andhrajyothy.com
# WARNING:root:#662 domain=canada.ca
# WARNING:root:#663 domain=jio.com
# WARNING:root:#664 domain=mawdoo3.com
# WARNING:root:#665 domain=kinokrad.co
# WARNING:root:#666 domain=kknews.cc
# WARNING:root:#667 domain=mercadolibre.com.ve
# WARNING:root:#668 domain=nownews.com
# WARNING:root:#669 domain=amazon.com.br
# WARNING:root:#670 domain=17track.net
# WARNING:root:#671 domain=google.com.co
# WARNING:root:#672 domain=uptodown.com
# WARNING:root:#673 domain=addthis.com
# WARNING:root:#674 domain=zomato.com
# WARNING:root:#675 domain=yeniakit.com.tr
# WARNING:root:#676 domain=znanija.com
# WARNING:root:#677 domain=shopee.tw
# WARNING:root:#678 domain=leboncoin.fr
# WARNING:root:#679 domain=toutiao.com
# WARNING:root:#680 domain=gamespot.com
# WARNING:root:#681 domain=dnevnik.ru
# WARNING:root:#682 domain=57e3ascxh1.com
# WARNING:root:#683 domain=wt.tmall.com
# WARNING:root:#684 domain=flvto.biz
# WARNING:root:#685 domain=dafont.com
# WARNING:root:#686 domain=h3lw971ym6.com
# WARNING:root:#687 domain=reclameaqui.com.br
# WARNING:root:#688 domain=olx.com.br
# WARNING:root:#689 domain=wordpress.org
# WARNING:root:#690 domain=haofang.net
# WARNING:root:#691 domain=so3ody.com
# WARNING:root:#692 domain=akamaized.net
# WARNING:root:#693 domain=gamer.com.tw
# WARNING:root:#694 domain=feedly.com
# WARNING:root:#695 domain=xe.com
# WARNING:root:#696 domain=lenovo.com
# WARNING:root:#697 domain=ea.com
# WARNING:root:#698 domain=wondershare.com
# WARNING:root:#699 domain=goo.ne.jp
# WARNING:root:#700 domain=vkaofq64zz.com
# WARNING:root:#701 domain=kissanime.ru
# WARNING:root:#702 domain=gotowebinar.com
# WARNING:root:#703 domain=coupang.com
# WARNING:root:#704 domain=douyu.com
# WARNING:root:#705 domain=turkiye.gov.tr
# WARNING:root:#706 domain=autodesk.com
# WARNING:root:#707 domain=tonlion.tmall.com
# WARNING:root:#708 domain=ytmp3.cc
# WARNING:root:#709 domain=urdupoint.com
# WARNING:root:#710 domain=123rf.com
# WARNING:root:#711 domain=dmm.com
# WARNING:root:#712 domain=plex.tv
# WARNING:root:#713 domain=nur.kz
# WARNING:root:#714 domain=dhl.com
# WARNING:root:#715 domain=itmedia.co.jp
# WARNING:root:#716 domain=newbalance.tmall.com
# WARNING:root:#717 domain=semir.tmall.com
# WARNING:root:#718 domain=discogs.com
# WARNING:root:#719 domain=as.com
# WARNING:root:#720 domain=bankmellat.ir
# WARNING:root:#721 domain=orange.fr
# WARNING:root:#722 domain=sakshi.com
# WARNING:root:#723 domain=ameba.jp
# WARNING:root:#724 domain=livedoor.com
# WARNING:root:#725 domain=topshop.tmall.com
# WARNING:root:#726 domain=zing.vn
# WARNING:root:#727 domain=visualstudio.com
# WARNING:root:#728 domain=dickies.tmall.com
# WARNING:root:#729 domain=op.gg
# WARNING:root:#730 domain=liansuo.com
# WARNING:root:#731 domain=it.tmall.com
# WARNING:root:#732 domain=uber.com
# WARNING:root:#733 domain=chip.de
# WARNING:root:#734 domain=cnzz.com
# WARNING:root:#735 domain=asus.com
# WARNING:root:#736 domain=epfindia.gov.in
# WARNING:root:#737 domain=llahnch259.com
# WARNING:root:#738 domain=olx.in
# WARNING:root:#739 domain=idxx1.cam
# WARNING:root:#740 domain=cnbcindonesia.com
# WARNING:root:#741 domain=jeanswest.tmall.com
# WARNING:root:#742 domain=correios.com.br
# WARNING:root:#743 domain=nfl.com
# WARNING:root:#744 domain=google.cl
# WARNING:root:#745 domain=bag.tmall.com
# WARNING:root:#746 domain=world.tmall.com
# WARNING:root:#747 domain=concursolutions.com
# WARNING:root:#748 domain=fazenda.gov.br
# WARNING:root:#749 domain=rottentomatoes.com
# WARNING:root:#750 domain=pikabu.ru
# WARNING:root:#751 domain=hubspot.com
# WARNING:root:#752 domain=uniqlo.com
# WARNING:root:#753 domain=subscene.com
# WARNING:root:#754 domain=cnnic.cn
# WARNING:root:#755 domain=kinogo.by
# WARNING:root:#756 domain=mayoclinic.org
# WARNING:root:#757 domain=leagueoflegends.com
# WARNING:root:#758 domain=6moxhf9rmm.com
# WARNING:root:#759 domain=kooora.com
# WARNING:root:#760 domain=wowhead.com
# WARNING:root:#761 domain=mercantilbanco.com
# WARNING:root:#762 domain=81.cn
# WARNING:root:#763 domain=youku.com
# WARNING:root:#764 domain=sozcu.com.tr
# WARNING:root:#765 domain=milliyet.com.tr
# WARNING:root:#766 domain=shopee.co.id
# WARNING:root:#767 domain=focus.cn
# WARNING:root:#768 domain=cima4u.tv
# WARNING:root:#769 domain=lachapelle.tmall.com
# WARNING:root:#770 domain=epicgames.com
# WARNING:root:#771 domain=gittigidiyor.com
# WARNING:root:#772 domain=service-now.com
# WARNING:root:#773 domain=hh.ru
# WARNING:root:#774 domain=soft98.ir
# WARNING:root:#775 domain=engadget.com
# WARNING:root:#776 domain=discover.com
# WARNING:root:#777 domain=nhk.or.jp
# WARNING:root:#778 domain=uchi.ru
# WARNING:root:#779 domain=runoob.com
# WARNING:root:#780 domain=urbandictionary.com
# WARNING:root:#781 domain=baike.com
# WARNING:root:#782 domain=web-hosting.com
# WARNING:root:#783 domain=skroutz.gr
# WARNING:root:#784 domain=espncricinfo.com
# WARNING:root:#785 domain=bitly.com
# WARNING:root:#786 domain=ku.tmall.com
# WARNING:root:#787 domain=24h.com.vn
# WARNING:root:#788 domain=dvoyy3qexr.com
# WARNING:root:#789 domain=motorsport.com
# WARNING:root:#790 domain=v2ex.com
# WARNING:root:#791 domain=uzone.id
# WARNING:root:#792 domain=book.tmall.com
# WARNING:root:#793 domain=thefreedictionary.com
# WARNING:root:#794 domain=gjirafa.com
# WARNING:root:#795 domain=hatena.ne.jp
# WARNING:root:#796 domain=myanmarload.com
# WARNING:root:#797 domain=javdoe.tv
# WARNING:root:#798 domain=ptt.cc
# WARNING:root:#799 domain=labanquepostale.fr
# WARNING:root:#800 domain=billdesk.com
# WARNING:root:#801 domain=seasonvar.ru
# WARNING:root:#802 domain=xbox.com
# WARNING:root:#803 domain=payu.in
# WARNING:root:#804 domain=c02o3mpych.com
# WARNING:root:#805 domain=y8.com
# WARNING:root:#806 domain=google.com.my
# WARNING:root:#807 domain=kolonsport.tmall.com
# WARNING:root:#808 domain=intentmedia.net
# WARNING:root:#809 domain=online-convert.com
# WARNING:root:#810 domain=afip.gob.ar
# WARNING:root:#811 domain=gap.com
# WARNING:root:#812 domain=jstor.org
# WARNING:root:#813 domain=nikkei.com
# WARNING:root:#814 domain=consultant.ru
# WARNING:root:#815 domain=nanxie.tmall.com
# WARNING:root:#816 domain=dw.com
# WARNING:root:#817 domain=auction.co.kr
# WARNING:root:#818 domain=hollisterco.tmall.com
# WARNING:root:#819 domain=urfs.tmall.com
# WARNING:root:#820 domain=bola.com
# WARNING:root:#821 domain=sonhoo.com
# WARNING:root:#822 domain=notion.so
# WARNING:root:#823 domain=rapidgator.net
# WARNING:root:#824 domain=editor.wix.com
# WARNING:root:#825 domain=kundelik.kz
# WARNING:root:#826 domain=irs.gov
# WARNING:root:#827 domain=state.gov
# WARNING:root:#828 domain=pole-emploi.fr
# WARNING:root:#829 domain=forever21.tmall.com
# WARNING:root:#830 domain=history.com
# WARNING:root:#831 domain=icloud.com
# WARNING:root:#832 domain=google.ch
# WARNING:root:#833 domain=scofield.tmall.com
# WARNING:root:#834 domain=ouo.io
# WARNING:root:#835 domain=delta.com
# WARNING:root:#836 domain=drom.ru
# WARNING:root:#837 domain=sputniknews.com
# WARNING:root:#838 domain=fairwhale.tmall.com
# WARNING:root:#839 domain=reverb.com
# WARNING:root:#840 domain=prom.ua
# WARNING:root:#841 domain=cttghjfhsw.com
# WARNING:root:#842 domain=gusuwang.com
# WARNING:root:#843 domain=earthmusic.tmall.com
# WARNING:root:#844 domain=3dmgame.com
# WARNING:root:#845 domain=nairaland.com
# WARNING:root:#846 domain=cisco.com
# WARNING:root:#847 domain=kayak.com
# WARNING:root:#848 domain=58.com
# WARNING:root:#849 domain=cricbuzz.com
# WARNING:root:#850 domain=padlet.com
# WARNING:root:#851 domain=harvard.edu
# WARNING:root:#852 domain=avgle.com
# WARNING:root:#853 domain=live.net
# WARNING:root:#854 domain=eland.tmall.com
# WARNING:root:#855 domain=jackjones.tmall.com
# WARNING:root:#856 domain=interia.pl
# WARNING:root:#857 domain=custhelp.com
# WARNING:root:#858 domain=entrepreneur.com
# WARNING:root:#859 domain=mi.com
# WARNING:root:#860 domain=myworkdayjobs.com
# WARNING:root:#861 domain=nanzhuang.tmall.com
# WARNING:root:#862 domain=usbank.com
# WARNING:root:#863 domain=jia.tmall.com
# WARNING:root:#864 domain=mytopgames.net
# WARNING:root:#865 domain=yodobashi.com
# WARNING:root:#866 domain=takelnk.com
# WARNING:root:#867 domain=spiegel.de
# WARNING:root:#868 domain=gaana.com
# WARNING:root:#869 domain=peacebird.tmall.com
# WARNING:root:#870 domain=sports.tmall.com
# WARNING:root:#871 domain=car.tmall.com
# WARNING:root:#872 domain=asana.com
# WARNING:root:#873 domain=shouji.tmall.com
# WARNING:root:#874 domain=idax.pro
# WARNING:root:#875 domain=gizmodo.com
# WARNING:root:#876 domain=retailmenot.com
# WARNING:root:#877 domain=alicdn.com
# WARNING:root:#878 domain=turnitin.com
# WARNING:root:#879 domain=indosport.com
# WARNING:root:#880 domain=septwolves.tmall.com
# WARNING:root:#881 domain=uidai.gov.in
# WARNING:root:#882 domain=watch.tmall.com
# WARNING:root:#883 domain=howtogeek.com
# WARNING:root:#884 domain=independent.co.uk
# WARNING:root:#885 domain=ih5.cn
# WARNING:root:#886 domain=caf.fr
# WARNING:root:#887 domain=ibicn.com
# WARNING:root:#888 domain=donga.com
# WARNING:root:#889 domain=farfetch.com
# WARNING:root:#890 domain=ifeng.com
# WARNING:root:#891 domain=wp.com
# WARNING:root:#892 domain=usnews.com
# WARNING:root:#893 domain=iyiou.com
# WARNING:root:#894 domain=provincial.com
# WARNING:root:#895 domain=mobile.de
# WARNING:root:#896 domain=film2movie.li
# WARNING:root:#897 domain=dai.tmall.com
# WARNING:root:#898 domain=cncn.org.cn
# WARNING:root:#899 domain=people.com
# WARNING:root:#900 domain=kahoot.it
# WARNING:root:#901 domain=nicsorts-accarade.com
# WARNING:root:#902 domain=drudgereport.com
# WARNING:root:#903 domain=myanimelist.net
# WARNING:root:#904 domain=strava.com
# WARNING:root:#905 domain=marksandspencer.tmall.com
# WARNING:root:#906 domain=nature.com
# WARNING:root:#907 domain=jumia.com.ng
# WARNING:root:#908 domain=schwab.com
# WARNING:root:#909 domain=hamariweb.com
# WARNING:root:#910 domain=bleacherreport.com
# WARNING:root:#911 domain=jb51.net
# WARNING:root:#912 domain=4shared.com
# WARNING:root:#913 domain=alnaharegypt.com
# WARNING:root:#914 domain=langsha.tmall.com
# WARNING:root:#915 domain=upwork.com
# WARNING:root:#916 domain=discoveryexpedition.tmall.com
# WARNING:root:#917 domain=dailycaller.com
# WARNING:root:#918 domain=nasa.gov
# WARNING:root:#919 domain=axisbank.com
# WARNING:root:#920 domain=teacherspayteachers.com
# WARNING:root:#921 domain=zol.com.cn
# WARNING:root:#922 domain=equirerecial.info
# WARNING:root:#923 domain=wowkeren.com
# WARNING:root:#924 domain=yespornplease.com
# WARNING:root:#925 domain=lemonde.fr
# WARNING:root:#926 domain=ssl-images-amazon.com
# WARNING:root:#927 domain=figma.com
# WARNING:root:#928 domain=rotumal.com
# WARNING:root:#929 domain=vidstream.to
# WARNING:root:#930 domain=dreamstime.com
# WARNING:root:#931 domain=zhibo8.cc
# WARNING:root:#932 domain=imis.tmall.com
# WARNING:root:#933 domain=pixlr.com
# WARNING:root:#934 domain=mos.ru
# WARNING:root:#935 domain=hespress.com
# WARNING:root:#936 domain=note.com
# WARNING:root:#937 domain=aa.com
# WARNING:root:#938 domain=flashscore.com
# WARNING:root:#939 domain=sportzwiki.com
# WARNING:root:#940 domain=meb.gov.tr
# WARNING:root:#941 domain=ebay.it
# WARNING:root:#942 domain=msi.com
# WARNING:root:#943 domain=photofans.cn
# WARNING:root:#944 domain=donya-e-eqtesad.com
# WARNING:root:#945 domain=lowes.com
# WARNING:root:#946 domain=voot.com
# WARNING:root:#947 domain=telegraph.co.uk
# WARNING:root:#948 domain=ceconline.com
# WARNING:root:#949 domain=bershka.tmall.com
# WARNING:root:#950 domain=filmix.co
# WARNING:root:#951 domain=efu.com.cn
# WARNING:root:#952 domain=behindwoods.com
# WARNING:root:#953 domain=ukr.net
# WARNING:root:#954 domain=mynet.com
# WARNING:root:#955 domain=iherb.com
# WARNING:root:#956 domain=cyberleninka.ru
# WARNING:root:#957 domain=ytimg.com
# WARNING:root:#958 domain=semanticscholar.org
# WARNING:root:#959 domain=cmoney.tw
# WARNING:root:#960 domain=envato.com
# WARNING:root:#961 domain=moneyforward.com
# WARNING:root:#962 domain=beeg.com
# WARNING:root:#963 domain=91jm.com
# WARNING:root:#964 domain=rajasthan.gov.in
# WARNING:root:#965 domain=jeuxvideo.com
# WARNING:root:#966 domain=hugedomains.com
# WARNING:root:#967 domain=ed.gov
# WARNING:root:#968 domain=expressvpn.com
# WARNING:root:#969 domain=ebay.fr
# WARNING:root:#970 domain=cabbeen.tmall.com
# WARNING:root:#971 domain=superuser.com
# WARNING:root:#972 domain=bola.net
# WARNING:root:#973 domain=kijiji.ca
# WARNING:root:#974 domain=enimerotiko.gr
# WARNING:root:#975 domain=bb.com.br
# WARNING:root:#976 domain=searchdimension.com
# WARNING:root:#977 domain=maniform.tmall.com
# WARNING:root:#978 domain=elcomercio.com
# WARNING:root:#979 domain=esprit.tmall.com
# WARNING:root:#980 domain=getawesome2.com
# WARNING:root:#981 domain=baby.tmall.com
# WARNING:root:#982 domain=intel.com
# WARNING:root:#983 domain=bookmyshow.com
# WARNING:root:#984 domain=folha.uol.com.br
# WARNING:root:#985 domain=lafuma.tmall.com
# WARNING:root:#986 domain=pantip.com
# WARNING:root:#987 domain=uptobox.com
# WARNING:root:#988 domain=dyson.tmall.com
# WARNING:root:#989 domain=dagospia.com
# WARNING:root:#990 domain=haberturk.com
# WARNING:root:#991 domain=investing-review.com
# WARNING:root:#992 domain=new3c.tmall.com
# WARNING:root:#993 domain=cengage.com
# WARNING:root:#994 domain=greenhouse.io
# WARNING:root:#995 domain=sbrf.ru
# WARNING:root:#996 domain=nesn.com
# WARNING:root:#997 domain=ted.com
# WARNING:root:#998 domain=chatwork.com
# WARNING:root:#999 domain=bandcamp.com
# WARNING:root:Processing ./dataset-top1000-padded/2/doh.pcap
# WARNING:root:#0 domain=google.com
# WARNING:root:#1 domain=youtube.com
# WARNING:root:#2 domain=facebook.com
# WARNING:root:#3 domain=tmall.com
# WARNING:root:#4 domain=baidu.com
# WARNING:root:#5 domain=qq.com
# WARNING:root:#6 domain=sohu.com
# WARNING:root:#7 domain=taobao.com
# WARNING:root:#8 domain=login.tmall.com
# WARNING:root:#9 domain=wikipedia.org
# WARNING:root:#10 domain=yahoo.com
# WARNING:root:#11 domain=amazon.com
# WARNING:root:#12 domain=360.cn
# WARNING:root:#13 domain=jd.com
# WARNING:root:#14 domain=weibo.com
# WARNING:root:#15 domain=sina.com.cn
# WARNING:root:#16 domain=pages.tmall.com
# WARNING:root:#17 domain=live.com
# WARNING:root:#18 domain=reddit.com
# WARNING:root:#19 domain=vk.com
# WARNING:root:#20 domain=okezone.com
# WARNING:root:#21 domain=netflix.com
# WARNING:root:#22 domain=blogspot.com
# WARNING:root:#23 domain=office.com
# WARNING:root:#24 domain=alipay.com
# WARNING:root:#25 domain=xinhuanet.com
# WARNING:root:#26 domain=csdn.net
# WARNING:root:#27 domain=instagram.com
# WARNING:root:#28 domain=yahoo.co.jp
# WARNING:root:#29 domain=aliexpress.com
# WARNING:root:#30 domain=microsoft.com
# WARNING:root:#31 domain=bing.com
# WARNING:root:#32 domain=google.com.hk
# WARNING:root:#33 domain=stackoverflow.com
# WARNING:root:#34 domain=spotify.com
# WARNING:root:#35 domain=naver.com
# WARNING:root:#36 domain=twitter.com
# WARNING:root:#37 domain=tribunnews.com
# WARNING:root:#38 domain=livejasmin.com
# WARNING:root:#39 domain=ebay.com
# WARNING:root:#40 domain=twitch.tv
# WARNING:root:#41 domain=amazon.co.jp
# WARNING:root:#42 domain=force.com
# WARNING:root:#43 domain=google.co.in
# WARNING:root:#44 domain=microsoftonline.com
# WARNING:root:#45 domain=tianya.cn
# WARNING:root:#46 domain=apple.com
# WARNING:root:#47 domain=myshopify.com
# WARNING:root:#48 domain=pornhub.com
# WARNING:root:#49 domain=yandex.ru
# WARNING:root:#50 domain=msn.com
# WARNING:root:#51 domain=adobe.com
# WARNING:root:#52 domain=panda.tv
# WARNING:root:#53 domain=linkedin.com
# WARNING:root:#54 domain=zhanqi.tv
# WARNING:root:#55 domain=dropbox.com
# WARNING:root:#56 domain=ERROR
# WARNING:root:#57 domain=wordpress.com
# WARNING:root:#58 domain=amazon.in
# WARNING:root:#59 domain=caijing.com.cn
# WARNING:root:#60 domain=mail.ru
# WARNING:root:#61 domain=imdb.com
# WARNING:root:#62 domain=china.com.cn
# WARNING:root:#63 domain=mama.cn
# WARNING:root:#64 domain=medium.com
# WARNING:root:#65 domain=google.com.br
# WARNING:root:#66 domain=bongacams.com
# WARNING:root:#67 domain=google.co.jp
# WARNING:root:#68 domain=hao123.com
# WARNING:root:#69 domain=amazon.co.uk
# WARNING:root:#70 domain=amazonaws.com
# WARNING:root:#71 domain=detik.com
# WARNING:root:#72 domain=rednet.cn
# WARNING:root:#73 domain=google.de
# WARNING:root:#74 domain=whatsapp.com
# WARNING:root:#75 domain=booking.com
# WARNING:root:#76 domain=xvideos.com
# WARNING:root:#77 domain=detail.tmall.com
# WARNING:root:#78 domain=amazon.de
# WARNING:root:#79 domain=ok.ru
# WARNING:root:#80 domain=instructure.com
# WARNING:root:#81 domain=tumblr.com
# WARNING:root:#82 domain=soso.com
# WARNING:root:#83 domain=bbc.com
# WARNING:root:#84 domain=sogou.com
# WARNING:root:#85 domain=google.cn
# WARNING:root:#86 domain=github.com
# WARNING:root:#87 domain=chase.com
# WARNING:root:#88 domain=paypal.com
# WARNING:root:#89 domain=espn.com
# WARNING:root:#90 domain=indeed.com
# WARNING:root:#91 domain=huanqiu.com
# WARNING:root:#92 domain=xhamster.com
# WARNING:root:#93 domain=google.ru
# WARNING:root:#94 domain=yy.com
# WARNING:root:#95 domain=nytimes.com
# WARNING:root:#96 domain=cnn.com
# WARNING:root:#97 domain=imgur.com
# WARNING:root:#98 domain=soundcloud.com
# WARNING:root:#99 domain=babytree.com
# WARNING:root:#100 domain=onlinesbi.com
# WARNING:root:#101 domain=17ok.com
# WARNING:root:#102 domain=stackexchange.com
# WARNING:root:#103 domain=walmart.com
# WARNING:root:#104 domain=aparat.com
# WARNING:root:#105 domain=bbc.co.uk
# WARNING:root:#106 domain=fandom.com
# WARNING:root:#107 domain=1688.com
# WARNING:root:#108 domain=ettoday.net
# WARNING:root:#109 domain=udemy.com
# WARNING:root:#110 domain=google.fr
# WARNING:root:#111 domain=google.it
# WARNING:root:#112 domain=freepik.com
# WARNING:root:#113 domain=so.com
# WARNING:root:#114 domain=shutterstock.com
# WARNING:root:#115 domain=pixnet.net
# WARNING:root:#116 domain=google.es
# WARNING:root:#117 domain=flipkart.com
# WARNING:root:#118 domain=kompas.com
# WARNING:root:#119 domain=etsy.com
# WARNING:root:#120 domain=nih.gov
# WARNING:root:#121 domain=roblox.com
# WARNING:root:#122 domain=mailchimp.com
# WARNING:root:#123 domain=sindonews.com
# WARNING:root:#124 domain=alibaba.com
# WARNING:root:#125 domain=google.com.tw
# WARNING:root:#126 domain=wetransfer.com
# WARNING:root:#127 domain=thestartmagazine.com
# WARNING:root:#128 domain=theguardian.com
# WARNING:root:#129 domain=jrj.com.cn
# WARNING:root:#130 domain=liputan6.com
# WARNING:root:#131 domain=salesforce.com
# WARNING:root:#132 domain=uol.com.br
# WARNING:root:#133 domain=google.co.uk
# WARNING:root:#134 domain=zendesk.com
# WARNING:root:#135 domain=indiatimes.com
# WARNING:root:#136 domain=canva.com
# WARNING:root:#137 domain=daum.net
# WARNING:root:#138 domain=office365.com
# WARNING:root:#139 domain=tokopedia.com
# WARNING:root:#140 domain=google.com.mx
# WARNING:root:#141 domain=google.com.sg
# WARNING:root:#142 domain=cnet.com
# WARNING:root:#143 domain=mercadolivre.com.br
# WARNING:root:#144 domain=wikihow.com
# WARNING:root:#145 domain=cnblogs.com
# WARNING:root:#146 domain=bilibili.com
# WARNING:root:#147 domain=digikala.com
# WARNING:root:#148 domain=bestbuy.com
# WARNING:root:#149 domain=slideshare.net
# WARNING:root:#150 domain=grid.id
# WARNING:root:#151 domain=okta.com
# WARNING:root:#152 domain=washingtonpost.com
# WARNING:root:#153 domain=t.co
# WARNING:root:#154 domain=google.com.tr
# WARNING:root:#155 domain=pinterest.com
# WARNING:root:#156 domain=yao.tmall.com
# WARNING:root:#157 domain=vice.com
# WARNING:root:#158 domain=savefrom.net
# WARNING:root:#159 domain=ebay.de
# WARNING:root:#160 domain=rakuten.co.jp
# WARNING:root:#161 domain=zhihu.com
# WARNING:root:#162 domain=discordapp.com
# WARNING:root:#163 domain=grammarly.com
# WARNING:root:#164 domain=globo.com
# WARNING:root:#165 domain=researchgate.net
# WARNING:root:#166 domain=w3schools.com
# WARNING:root:#167 domain=vimeo.com
# WARNING:root:#168 domain=ups.com
# WARNING:root:#169 domain=avito.ru
# WARNING:root:#170 domain=craigslist.org
# WARNING:root:#171 domain=archive.org
# WARNING:root:#172 domain=xnxx.com
# WARNING:root:#173 domain=line.me
# WARNING:root:#174 domain=telegram.org
# WARNING:root:#175 domain=godaddy.com
# WARNING:root:#176 domain=metropoles.com
# WARNING:root:#177 domain=hdfcbank.com
# WARNING:root:#178 domain=forbes.com
# WARNING:root:#179 domain=chaturbate.com
# WARNING:root:#180 domain=speedtest.net
# WARNING:root:#181 domain=6.cn
# WARNING:root:#182 domain=amazon.ca
# WARNING:root:#183 domain=duckduckgo.com
# WARNING:root:#184 domain=aliyun.com
# WARNING:root:#185 domain=wellsfargo.com
# WARNING:root:#186 domain=ask.com
# WARNING:root:#187 domain=mediafire.com
# WARNING:root:#188 domain=abs-cbn.com
# WARNING:root:#189 domain=amazon.it
# WARNING:root:#190 domain=3c.tmall.com
# WARNING:root:#191 domain=amazon.fr
# WARNING:root:#192 domain=ltn.com.tw
# WARNING:root:#193 domain=jiameng.com
# WARNING:root:#194 domain=mozilla.org
# WARNING:root:#195 domain=scribd.com
# WARNING:root:#196 domain=academia.edu
# WARNING:root:#197 domain=varzesh3.com
# WARNING:root:#198 domain=telewebion.com
# WARNING:root:#199 domain=google.com.sa
# WARNING:root:#200 domain=gmw.cn
# WARNING:root:#201 domain=163.com
# WARNING:root:#202 domain=fedex.com
# WARNING:root:#203 domain=google.com.eg
# WARNING:root:#204 domain=thepiratebay.org
# WARNING:root:#205 domain=manoramaonline.com
# WARNING:root:#206 domain=jianshu.com
# WARNING:root:#207 domain=bet365.com
# WARNING:root:#208 domain=google.ca
# WARNING:root:#209 domain=dailymotion.com
# WARNING:root:#210 domain=ilovepdf.com
# WARNING:root:#211 domain=zillow.com
# WARNING:root:#212 domain=gohoi.com
# WARNING:root:#213 domain=quora.com
# WARNING:root:#214 domain=unsplash.com
# WARNING:root:#215 domain=thesaurus.com
# WARNING:root:#216 domain=businessinsider.com
# WARNING:root:#217 domain=y2mate.com
# WARNING:root:#218 domain=primevideo.com
# WARNING:root:#219 domain=gome.com.cn
# WARNING:root:#220 domain=trello.com
# WARNING:root:#221 domain=wix.com
# WARNING:root:#222 domain=tistory.com
# WARNING:root:#223 domain=usps.com
# WARNING:root:#224 domain=setn.com
# WARNING:root:#225 domain=taboola.com
# WARNING:root:#226 domain=chouftv.ma
# WARNING:root:#227 domain=mega.nz
# WARNING:root:#228 domain=amazon.es
# WARNING:root:#229 domain=iqiyi.com
# WARNING:root:#230 domain=icicibank.com
# WARNING:root:#231 domain=google.co.id
# WARNING:root:#232 domain=capitalone.com
# WARNING:root:#233 domain=momoshop.com.tw
# WARNING:root:#234 domain=ladbible.com
# WARNING:root:#235 domain=evernote.com
# WARNING:root:#236 domain=sciencedirect.com
# WARNING:root:#237 domain=thethao247.vn
# WARNING:root:#238 domain=ebay.co.uk
# WARNING:root:#239 domain=messenger.com
# WARNING:root:#240 domain=hulu.com
# WARNING:root:#241 domain=healthline.com
# WARNING:root:#242 domain=google.com.ar
# WARNING:root:#243 domain=sigonews.com
# WARNING:root:#244 domain=nicovideo.jp
# WARNING:root:#245 domain=google.co.th
# WARNING:root:#246 domain=otvfoco.com.br
# WARNING:root:#247 domain=nvzhuang.tmall.com
# WARNING:root:#248 domain=suara.com
# WARNING:root:#249 domain=gfycat.com
# WARNING:root:#250 domain=youm7.com
# WARNING:root:#251 domain=skype.com
# WARNING:root:#252 domain=idntimes.com
# WARNING:root:#253 domain=sportbible.com
# WARNING:root:#254 domain=foxnews.com
# WARNING:root:#255 domain=weebly.com
# WARNING:root:#256 domain=reverso.net
# WARNING:root:#257 domain=uniqlo.tmall.com
# WARNING:root:#258 domain=scol.com.cn
# WARNING:root:#259 domain=target.com
# WARNING:root:#260 domain=itfactly.com
# WARNING:root:#261 domain=yts.lt
# WARNING:root:#262 domain=food.tmall.com
# WARNING:root:#263 domain=quizlet.com
# WARNING:root:#264 domain=youporn.com
# WARNING:root:#265 domain=geeksforgeeks.org
# WARNING:root:#266 domain=breitbart.com
# WARNING:root:#267 domain=box.com
# WARNING:root:#268 domain=techofires.com
# WARNING:root:#269 domain=dailymail.co.uk
# WARNING:root:#270 domain=asos.com
# WARNING:root:#271 domain=youth.cn
# WARNING:root:#272 domain=blogger.com
# WARNING:root:#273 domain=zoom.us
# WARNING:root:#274 domain=subject.tmall.com
# WARNING:root:#275 domain=namnak.com
# WARNING:root:#276 domain=ameblo.jp
# WARNING:root:#277 domain=tripadvisor.com
# ...
# WARNING:root:#579 domain=o3sndvzo25.com
# WARNING:root:#580 domain=indiatoday.in
# WARNING:root:#581 domain=google.co.za
# WARNING:root:#582 domain=narvar.com
# WARNING:root:#583 domain=go.com
# WARNING:root:#584 domain=motor1.com
# WARNING:root:#585 domain=dcard.tw
# WARNING:root:#586 domain=trendingnow.video
# WARNING:root:#587 domain=dhl.de
# WARNING:root:#588 domain=sabq.org
# WARNING:root:#589 domain=makemytrip.com
# WARNING:root:#590 domain=rezka.ag
# WARNING:root:#591 domain=pmlw0efk4x.com
# WARNING:root:#592 domain=nike.tmall.com
# WARNING:root:#593 domain=pngtree.com
# WARNING:root:#594 domain=buffer.com
# WARNING:root:#595 domain=chinadaily.com.cn
# WARNING:root:#596 domain=duolingo.com
# WARNING:root:#597 domain=google.az
# WARNING:root:#598 domain=crunchyroll.com
# WARNING:root:#599 domain=gyazo.com
# WARNING:root:#600 domain=wiley.com
# WARNING:root:#601 domain=ria.ru
# WARNING:root:#602 domain=gmarket.co.kr
# WARNING:root:#603 domain=ogrfi3uyt7.com
# WARNING:root:#604 domain=groupon.com
# WARNING:root:#605 domain=typeform.com
# WARNING:root:#606 domain=qpps.xyz
# WARNING:root:#607 domain=npr.org
# WARNING:root:#608 domain=verizonwireless.com
# WARNING:root:#609 domain=rbc.ru
# WARNING:root:#610 domain=herokuapp.com
# WARNING:root:#611 domain=huffpost.com
# WARNING:root:#612 domain=4exlkjnngs.com
# WARNING:root:#613 domain=teamviewer.com
# WARNING:root:#614 domain=att.com
# WARNING:root:#615 domain=nbcnews.com
# WARNING:root:#616 domain=dictionary.com
# WARNING:root:#617 domain=tabelog.com
# WARNING:root:#618 domain=creditchina.gov.cn
# WARNING:root:#619 domain=cbssports.com
# WARNING:root:#620 domain=qualtrics.com
# WARNING:root:#621 domain=deepl.com
# WARNING:root:#622 domain=animeflv.net
# WARNING:root:#623 domain=umeng.com
# WARNING:root:#624 domain=olx.pl
# WARNING:root:#625 domain=flickr.com
# WARNING:root:#626 domain=php.net
# WARNING:root:#627 domain=creditonebank.com
# WARNING:root:#628 domain=chron.com
# WARNING:root:#629 domain=narcity.com
# WARNING:root:#630 domain=ibm.com
# WARNING:root:#631 domain=premierleague.com
# WARNING:root:#632 domain=zara.com
# WARNING:root:#633 domain=ivi.ru
# WARNING:root:#634 domain=seznam.cz
# WARNING:root:#635 domain=myway.com
# WARNING:root:#636 domain=blog.me
# WARNING:root:#637 domain=studfile.net
# WARNING:root:#638 domain=exoclick.com
# WARNING:root:#639 domain=farsnews.com
# WARNING:root:#640 domain=livescore.com
# WARNING:root:#641 domain=dalfak.com
# WARNING:root:#642 domain=ticketmaster.com
# WARNING:root:#643 domain=gainreel.tmall.com
# WARNING:root:#644 domain=hotels.com
# WARNING:root:#645 domain=rokna.net
# WARNING:root:#646 domain=elmundo.es
# WARNING:root:#647 domain=shutterfly.com
# WARNING:root:#648 domain=hatenablog.com
# WARNING:root:#649 domain=xianjichina.com
# WARNING:root:#650 domain=techradar.com
# WARNING:root:#651 domain=xpx7heciz9.com
# WARNING:root:#652 domain=ozon.ru
# WARNING:root:#653 domain=biblegateway.com
# WARNING:root:#654 domain=360doc.com
# WARNING:root:#655 domain=ultimate-guitar.com
# WARNING:root:#656 domain=americanexpress.com
# WARNING:root:#657 domain=uioxj.xyz
# WARNING:root:#658 domain=anta.tmall.com
# WARNING:root:#659 domain=royalbank.com
# WARNING:root:#660 domain=sarkariresult.com
# WARNING:root:#661 domain=andhrajyothy.com
# WARNING:root:#662 domain=canada.ca
# WARNING:root:#663 domain=jio.com
# WARNING:root:#664 domain=mawdoo3.com
# WARNING:root:#665 domain=kinokrad.co
# WARNING:root:#666 domain=kknews.cc
# WARNING:root:#667 domain=mercadolibre.com.ve
# WARNING:root:#668 domain=nownews.com
# WARNING:root:#669 domain=amazon.com.br
# WARNING:root:#670 domain=17track.net
# WARNING:root:#671 domain=google.com.co
# WARNING:root:#672 domain=uptodown.com
# WARNING:root:#673 domain=addthis.com
# WARNING:root:#674 domain=zomato.com
# WARNING:root:#675 domain=yeniakit.com.tr
# WARNING:root:#676 domain=znanija.com
# WARNING:root:#677 domain=shopee.tw
# WARNING:root:#678 domain=leboncoin.fr
# WARNING:root:#679 domain=toutiao.com
# WARNING:root:#680 domain=gamespot.com
# WARNING:root:#681 domain=dnevnik.ru
# WARNING:root:#682 domain=57e3ascxh1.com
# WARNING:root:#683 domain=wt.tmall.com
# WARNING:root:#684 domain=flvto.biz
# WARNING:root:#685 domain=dafont.com
# WARNING:root:#686 domain=h3lw971ym6.com
# WARNING:root:#687 domain=reclameaqui.com.br
# WARNING:root:#688 domain=olx.com.br
# WARNING:root:#689 domain=wordpress.org
# WARNING:root:#690 domain=haofang.net
# WARNING:root:#691 domain=so3ody.com
# WARNING:root:#692 domain=akamaized.net
# WARNING:root:#693 domain=gamer.com.tw
# WARNING:root:#694 domain=feedly.com
# WARNING:root:#695 domain=xe.com
# WARNING:root:#696 domain=lenovo.com
# WARNING:root:#697 domain=ea.com
# WARNING:root:#698 domain=wondershare.com
# WARNING:root:#699 domain=goo.ne.jp
# WARNING:root:#700 domain=vkaofq64zz.com
# WARNING:root:#701 domain=kissanime.ru
# WARNING:root:#702 domain=gotowebinar.com
# WARNING:root:#703 domain=coupang.com
# WARNING:root:#704 domain=douyu.com
# WARNING:root:#705 domain=turkiye.gov.tr
# WARNING:root:#706 domain=autodesk.com
# WARNING:root:#707 domain=tonlion.tmall.com
# WARNING:root:#708 domain=ytmp3.cc
# WARNING:root:#709 domain=urdupoint.com
# WARNING:root:#710 domain=123rf.com
# WARNING:root:#711 domain=dmm.com
# WARNING:root:#712 domain=plex.tv
# WARNING:root:#713 domain=nur.kz
# WARNING:root:#714 domain=dhl.com
# WARNING:root:#715 domain=itmedia.co.jp
# WARNING:root:#716 domain=newbalance.tmall.com
# WARNING:root:#717 domain=semir.tmall.com
# WARNING:root:#718 domain=discogs.com
# WARNING:root:#719 domain=as.com
# WARNING:root:#720 domain=bankmellat.ir
# WARNING:root:#721 domain=orange.fr
# WARNING:root:#722 domain=sakshi.com
# WARNING:root:#723 domain=ameba.jp
# WARNING:root:#724 domain=livedoor.com
# WARNING:root:#725 domain=topshop.tmall.com
# WARNING:root:#726 domain=zing.vn
# WARNING:root:#727 domain=visualstudio.com
# WARNING:root:#728 domain=dickies.tmall.com
# WARNING:root:#729 domain=op.gg
# WARNING:root:#730 domain=liansuo.com
# WARNING:root:#731 domain=it.tmall.com
# WARNING:root:#732 domain=uber.com
# WARNING:root:#733 domain=chip.de
# WARNING:root:#734 domain=cnzz.com
# WARNING:root:#735 domain=asus.com
# WARNING:root:#736 domain=epfindia.gov.in
# WARNING:root:#737 domain=llahnch259.com
# WARNING:root:#738 domain=olx.in
# WARNING:root:#739 domain=idxx1.cam
# WARNING:root:#740 domain=cnbcindonesia.com
# WARNING:root:#741 domain=jeanswest.tmall.com
# WARNING:root:#742 domain=correios.com.br
# WARNING:root:#743 domain=nfl.com
# WARNING:root:#744 domain=google.cl
# WARNING:root:#745 domain=bag.tmall.com
# WARNING:root:#746 domain=world.tmall.com
# WARNING:root:#747 domain=concursolutions.com
# WARNING:root:#748 domain=fazenda.gov.br
# WARNING:root:#749 domain=rottentomatoes.com
# WARNING:root:#750 domain=pikabu.ru
# WARNING:root:#751 domain=hubspot.com
# WARNING:root:#752 domain=uniqlo.com
# WARNING:root:#753 domain=subscene.com
# WARNING:root:#754 domain=cnnic.cn
# WARNING:root:#755 domain=kinogo.by
# WARNING:root:#756 domain=mayoclinic.org
# WARNING:root:#757 domain=leagueoflegends.com
# WARNING:root:#758 domain=6moxhf9rmm.com
# WARNING:root:#759 domain=kooora.com
# WARNING:root:#760 domain=wowhead.com
# WARNING:root:#761 domain=mercantilbanco.com
# WARNING:root:#762 domain=81.cn
# WARNING:root:#763 domain=youku.com
# WARNING:root:#764 domain=sozcu.com.tr
# WARNING:root:#765 domain=milliyet.com.tr
# WARNING:root:#766 domain=shopee.co.id
# WARNING:root:#767 domain=focus.cn
# WARNING:root:#768 domain=cima4u.tv
# WARNING:root:#769 domain=lachapelle.tmall.com
# WARNING:root:#770 domain=epicgames.com
# WARNING:root:#771 domain=gittigidiyor.com
# WARNING:root:#772 domain=service-now.com
# WARNING:root:#773 domain=hh.ru
# WARNING:root:#774 domain=soft98.ir
# WARNING:root:#775 domain=engadget.com
# WARNING:root:#776 domain=discover.com
# WARNING:root:#777 domain=nhk.or.jp
# WARNING:root:#778 domain=uchi.ru
# WARNING:root:#779 domain=runoob.com
# WARNING:root:#780 domain=urbandictionary.com
# WARNING:root:#781 domain=baike.com
# WARNING:root:#782 domain=web-hosting.com
# WARNING:root:#783 domain=skroutz.gr
# WARNING:root:#784 domain=espncricinfo.com
# WARNING:root:#785 domain=bitly.com
# WARNING:root:#786 domain=ku.tmall.com
# WARNING:root:#787 domain=24h.com.vn
# WARNING:root:#788 domain=dvoyy3qexr.com
# WARNING:root:#789 domain=motorsport.com
# WARNING:root:#790 domain=v2ex.com
# WARNING:root:#791 domain=uzone.id
# WARNING:root:#792 domain=book.tmall.com
# WARNING:root:#793 domain=thefreedictionary.com
# WARNING:root:#794 domain=gjirafa.com
# WARNING:root:#795 domain=hatena.ne.jp
# WARNING:root:#796 domain=myanmarload.com
# WARNING:root:#797 domain=javdoe.tv
# WARNING:root:#798 domain=ptt.cc
# WARNING:root:#799 domain=labanquepostale.fr
# WARNING:root:#800 domain=billdesk.com
# WARNING:root:#801 domain=seasonvar.ru
# WARNING:root:#802 domain=xbox.com
# WARNING:root:#803 domain=payu.in
# WARNING:root:#804 domain=c02o3mpych.com
# WARNING:root:#805 domain=y8.com
# WARNING:root:#806 domain=google.com.my
# WARNING:root:#807 domain=kolonsport.tmall.com
# WARNING:root:#808 domain=intentmedia.net
# WARNING:root:#809 domain=online-convert.com
# WARNING:root:#810 domain=afip.gob.ar
# WARNING:root:#811 domain=gap.com
# WARNING:root:#812 domain=jstor.org
# WARNING:root:#813 domain=nikkei.com
# WARNING:root:#814 domain=consultant.ru
# WARNING:root:#815 domain=nanxie.tmall.com
# WARNING:root:#816 domain=dw.com
# WARNING:root:#817 domain=auction.co.kr
# WARNING:root:#818 domain=hollisterco.tmall.com
# WARNING:root:#819 domain=urfs.tmall.com
# WARNING:root:#820 domain=bola.com
# WARNING:root:#821 domain=sonhoo.com
# WARNING:root:#822 domain=notion.so
# WARNING:root:#823 domain=rapidgator.net
# WARNING:root:#824 domain=editor.wix.com
# WARNING:root:#825 domain=kundelik.kz
# WARNING:root:#826 domain=irs.gov
# WARNING:root:#827 domain=state.gov
# WARNING:root:#828 domain=pole-emploi.fr
# WARNING:root:#829 domain=forever21.tmall.com
# WARNING:root:#830 domain=history.com
# WARNING:root:#831 domain=icloud.com
# WARNING:root:#832 domain=google.ch
# WARNING:root:#833 domain=scofield.tmall.com
# WARNING:root:#834 domain=ouo.io
# WARNING:root:#835 domain=delta.com
# WARNING:root:#836 domain=drom.ru
# WARNING:root:#837 domain=sputniknews.com
# WARNING:root:#838 domain=fairwhale.tmall.com
# WARNING:root:#839 domain=reverb.com
# WARNING:root:#840 domain=prom.ua
# WARNING:root:#841 domain=cttghjfhsw.com
# WARNING:root:#842 domain=gusuwang.com
# WARNING:root:#843 domain=earthmusic.tmall.com
# WARNING:root:#844 domain=3dmgame.com
# WARNING:root:#845 domain=nairaland.com
# WARNING:root:#846 domain=cisco.com
# WARNING:root:#847 domain=kayak.com
# WARNING:root:#848 domain=58.com
# WARNING:root:#849 domain=cricbuzz.com
# WARNING:root:#850 domain=padlet.com
# WARNING:root:#851 domain=harvard.edu
# WARNING:root:#852 domain=avgle.com
# WARNING:root:#853 domain=live.net
# WARNING:root:#854 domain=eland.tmall.com
# WARNING:root:#855 domain=jackjones.tmall.com
# WARNING:root:#856 domain=interia.pl
# WARNING:root:#857 domain=custhelp.com
# WARNING:root:#858 domain=entrepreneur.com
# WARNING:root:#859 domain=mi.com
# WARNING:root:#860 domain=myworkdayjobs.com
# WARNING:root:#861 domain=nanzhuang.tmall.com
# WARNING:root:#862 domain=usbank.com
# WARNING:root:#863 domain=jia.tmall.com
# WARNING:root:#864 domain=mytopgames.net
# WARNING:root:#865 domain=yodobashi.com
# WARNING:root:#866 domain=takelnk.com
# WARNING:root:#867 domain=spiegel.de
# WARNING:root:#868 domain=gaana.com
# WARNING:root:#869 domain=peacebird.tmall.com
# WARNING:root:#870 domain=sports.tmall.com
# WARNING:root:#871 domain=car.tmall.com
# WARNING:root:#872 domain=asana.com
# WARNING:root:#873 domain=shouji.tmall.com
# WARNING:root:#874 domain=idax.pro
# WARNING:root:#875 domain=gizmodo.com
# WARNING:root:#876 domain=retailmenot.com
# WARNING:root:#877 domain=alicdn.com
# WARNING:root:#878 domain=turnitin.com
# WARNING:root:#879 domain=indosport.com
# WARNING:root:#880 domain=septwolves.tmall.com
# WARNING:root:#881 domain=uidai.gov.in
# WARNING:root:#882 domain=watch.tmall.com
# WARNING:root:#883 domain=howtogeek.com
# WARNING:root:#884 domain=independent.co.uk
# WARNING:root:#885 domain=ih5.cn
# WARNING:root:#886 domain=caf.fr
# WARNING:root:#887 domain=ibicn.com
# WARNING:root:#888 domain=donga.com
# WARNING:root:#889 domain=farfetch.com
# WARNING:root:#890 domain=ifeng.com
# WARNING:root:#891 domain=wp.com
# WARNING:root:#892 domain=usnews.com
# WARNING:root:#893 domain=iyiou.com
# WARNING:root:#894 domain=provincial.com
# WARNING:root:#895 domain=mobile.de
# WARNING:root:#896 domain=film2movie.li
# WARNING:root:#897 domain=dai.tmall.com
# WARNING:root:#898 domain=cncn.org.cn
# WARNING:root:#899 domain=people.com
# WARNING:root:#900 domain=kahoot.it
# WARNING:root:#901 domain=nicsorts-accarade.com
# WARNING:root:#902 domain=drudgereport.com
# WARNING:root:#903 domain=myanimelist.net
# WARNING:root:#904 domain=strava.com
# WARNING:root:#905 domain=marksandspencer.tmall.com
# WARNING:root:#906 domain=nature.com
# WARNING:root:#907 domain=jumia.com.ng
# WARNING:root:#908 domain=schwab.com
# WARNING:root:#909 domain=hamariweb.com
# WARNING:root:#910 domain=bleacherreport.com
# WARNING:root:#911 domain=jb51.net
# WARNING:root:#912 domain=4shared.com
# WARNING:root:#913 domain=alnaharegypt.com
# WARNING:root:#914 domain=langsha.tmall.com
# WARNING:root:#915 domain=upwork.com
# WARNING:root:#916 domain=discoveryexpedition.tmall.com
# WARNING:root:#917 domain=dailycaller.com
# WARNING:root:#918 domain=nasa.gov
# WARNING:root:#919 domain=axisbank.com
# WARNING:root:#920 domain=teacherspayteachers.com
# WARNING:root:#921 domain=zol.com.cn
# WARNING:root:#922 domain=equirerecial.info
# WARNING:root:#923 domain=wowkeren.com
# WARNING:root:#924 domain=yespornplease.com
# WARNING:root:#925 domain=lemonde.fr
# WARNING:root:#926 domain=ssl-images-amazon.com
# WARNING:root:#927 domain=figma.com
# WARNING:root:#928 domain=rotumal.com
# WARNING:root:#929 domain=vidstream.to
# WARNING:root:#930 domain=dreamstime.com
# WARNING:root:#931 domain=zhibo8.cc
# WARNING:root:#932 domain=imis.tmall.com
# WARNING:root:#933 domain=pixlr.com
# WARNING:root:#934 domain=mos.ru
# WARNING:root:#935 domain=hespress.com
# WARNING:root:#936 domain=note.com
# WARNING:root:#937 domain=aa.com
# WARNING:root:#938 domain=flashscore.com
# WARNING:root:#939 domain=sportzwiki.com
# WARNING:root:#940 domain=meb.gov.tr
# WARNING:root:#941 domain=ebay.it
# WARNING:root:#942 domain=msi.com
# WARNING:root:#943 domain=photofans.cn
# WARNING:root:#944 domain=donya-e-eqtesad.com
# WARNING:root:#945 domain=lowes.com
# WARNING:root:#946 domain=voot.com
# WARNING:root:#947 domain=telegraph.co.uk
# WARNING:root:#948 domain=ceconline.com
# WARNING:root:#949 domain=bershka.tmall.com
# WARNING:root:#950 domain=filmix.co
# WARNING:root:#951 domain=efu.com.cn
# WARNING:root:#952 domain=behindwoods.com
# WARNING:root:#953 domain=ukr.net
# WARNING:root:#954 domain=mynet.com
# WARNING:root:#955 domain=iherb.com
# WARNING:root:#956 domain=cyberleninka.ru
# WARNING:root:#957 domain=ytimg.com
# WARNING:root:#958 domain=semanticscholar.org
# WARNING:root:#959 domain=cmoney.tw
# WARNING:root:#960 domain=envato.com
# WARNING:root:#961 domain=moneyforward.com
# WARNING:root:#962 domain=beeg.com
# WARNING:root:#963 domain=91jm.com
# WARNING:root:#964 domain=rajasthan.gov.in
# WARNING:root:#965 domain=jeuxvideo.com
# WARNING:root:#966 domain=hugedomains.com
# WARNING:root:#967 domain=ed.gov
# WARNING:root:#968 domain=expressvpn.com
# WARNING:root:#969 domain=ebay.fr
# WARNING:root:#970 domain=cabbeen.tmall.com
# WARNING:root:#971 domain=superuser.com
# WARNING:root:#972 domain=bola.net
# WARNING:root:#973 domain=kijiji.ca
# WARNING:root:#974 domain=enimerotiko.gr
# WARNING:root:#975 domain=bb.com.br
# WARNING:root:#976 domain=searchdimension.com
# WARNING:root:#977 domain=maniform.tmall.com
# WARNING:root:#978 domain=elcomercio.com
# WARNING:root:#979 domain=esprit.tmall.com
# WARNING:root:#980 domain=getawesome2.com
# WARNING:root:#981 domain=baby.tmall.com
# WARNING:root:#982 domain=intel.com
# WARNING:root:#983 domain=bookmyshow.com
# WARNING:root:#984 domain=folha.uol.com.br
# WARNING:root:#985 domain=lafuma.tmall.com
# WARNING:root:#986 domain=pantip.com
# WARNING:root:#987 domain=uptobox.com
# WARNING:root:#988 domain=dyson.tmall.com
# WARNING:root:#989 domain=dagospia.com
# WARNING:root:#990 domain=haberturk.com
# WARNING:root:#991 domain=investing-review.com
# WARNING:root:#992 domain=new3c.tmall.com
# WARNING:root:#993 domain=cengage.com
# WARNING:root:#994 domain=greenhouse.io
# WARNING:root:#995 domain=sbrf.ru
# WARNING:root:#996 domain=nesn.com
# WARNING:root:#997 domain=ted.com
# WARNING:root:#998 domain=chatwork.com
# WARNING:root:#999 domain=bandcamp.com
